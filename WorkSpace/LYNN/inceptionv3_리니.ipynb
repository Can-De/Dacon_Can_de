# %% [markdown]
# <a href="https://www.kaggle.com/code/proxzima/skin-cancer-mnist-resnet50-iv3-vgg16-19-googlenet?scriptVersionId=105345653" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div align="center">
# <font size="6"> Skin Cancer MNIST Classification (ResNet50, InceptionV3, VGG16, VGG19, GoogLeNet)  </font>
# </div>

# %% [markdown]
# # 1. Convolutional Neural Network

# %% [markdown]
# <div align="center">
# <font size="4"> Residual learning: a building block.  </font>
# </div>
#
# <img align="left" src="https://raw.githubusercontent.com/kabartay/kaggle-siim-isic-melanoma-classification/master/materials/A-cell-from-the-Residual-Network-architecture-The-identity-connection-helps-to-reduce.png" width="350" style='margin-right:10px'/>
# The degradation (of training accuracy) indicates that not all systems are similarly easy to optimize. In [Kaiming He et all. 2015] the degradation problem is adressed by introducing a deep residual learning framework. Instead of hoping each few stacked layers directly fit a desired underlying mapping, we explicitly let these layers fit a residual mapping. Formally, denoting the desired underlying mapping as H(x), we let the stacked nonlinear layers fit another mapping of F(x) := H(x)−x. The original mapping is recast into F(x)+x. We hypothesize that it is easier to optimize the residual mapping than to optimize the original, unreferenced mapping. To the extreme, if an identity mapping were optimal, it would be easier to push the residual to zero than to fit an identity mapping by a stack of nonlinear layers.
#
# The formulation of F(x)+x can be realized by feedforward neural networks with ''shortcut connections'' (see scheme). Shortcut connections are those skipping one or
# more layers. In our case, the shortcut connections simply perform identity mapping, and their outputs are added to the outputs of the stacked layers (see scheme). Identity shortcut connections add neither extra parameter nor computational complexity. The entire network can still be trained end-to-end by SGD with backpropagation, and can be easily implemented using common libraries
#
# &nbsp;
# &nbsp;
#
# <div align="center">
# <font size="4"> Example of ResNet50 vs Xception vs Inception-V3 vs VGG-19 vs VGG-16 as reference model.  </font>
# <img align="center" src="https://github.com/PROxZIMA/Skin-Cancer-MNIST-HAM10000/raw/master/assets/ResNet50%20vs%20Xception%20vs%20Inception-V3%20vs%20VGG-19%20vs%20VGG-16.png" width="870" />
# </div>
#
# &nbsp;
# &nbsp;
#
# <div align="center">
# <font size="4"> Detailed example of GoogLeNet a.k.a. Inception-V1 (Szegedy, 2015) as reference model.  </font>
# <img align="center" src="https://github.com/PROxZIMA/Skin-Cancer-MNIST-HAM10000/raw/master/assets/GoogLeNet%20(Inception-V1).png" />
# </div>

# %% [markdown]
# # 2. Libraries

# %% [markdown]
# # 2.1 Load Required Libraries

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# os.environ['TF_CPP_MIN_LOG_LEVEL'] 에 입력될 수 있는 값은 아래와 같습니다.
# 0 = all messages are logged (default behavior)
# 1 = INFO messages are not printed
# 2 = INFO and WARNING messages are not printed
# 3 = INFO, WARNING, and ERROR messages are not printed

import re
import gc
import sys
import glob
import pathlib
# path 경로에서 폴더 있는지 없는지 확인해줌 말고도 기능 많음
import time
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from glob import glob
# 파일명을 리스트 형식으로 반환

import cv2

import PIL
from PIL import Image
# 이미지 컷팅

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight

from collections import Counter
# =value_counts

from warnings import filterwarnings
filterwarnings('ignore')

SEED=123
np.random.seed(SEED)

# %%
import random
import pandas as pd
import numpy as np
import os
import cv2
from tqdm.auto import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import torchvision.models as models

from sklearn import metrics
from sklearn.preprocessing import StandardScaler, LabelEncoder

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2.2 Load TensorFlow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.layers import (
    Input, Dense, Conv2D, Flatten, Activation, Dropout, BatchNormalization,
    MaxPooling2D, AveragePooling2D, ZeroPadding2D, GlobalAveragePooling2D, GlobalMaxPooling2D, add
)
from keras.layers.merging import concatenate

from tensorflow.python.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
# Callback : 특정 이벤트가 발생할 때마다 Tensorflow는 개발자가 등록해 둔 Callback 함수들을 호출
# EalryStopping : 일정 성능이 나지 않으면 멈추기

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import plot_model
# model.summary 시각화 **중요

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input

tf.get_logger().setLevel('ERROR')

# %%
CFG = dict(
    batch_size            =  20,   # 8; 16; 32; 64; bigger batch size => moemry allocation issue
    epochs                =  30,   # 5; 10; 20;
    last_trainable_layers =   0,
    verbose               =   1,   # 0; 1
    fontsize              =  14,

    # Images sizes
    img_width             = 512,   # 600 Original -> 150
    img_height            = 512,   # 450 Original -> 112

    # Images augs
    ROTATION_RANGE        =  90.0,
    ZOOM_RANGE            =   0.1,
    HSHIFT_RANGE          =   0.1,
    WSHIFT_RANGE          =   0.1,
    HFLIP                 = False,
    VFLIP                 = False,

    # Postprocessing
    stopper_patience      =  10,   # 0.01; 0.05; 0.1; 0.2;
    run_functions_eagerly = False

    SEED = 41
)
# CFG = {
#     'IMG_SIZE':512,
#     'EPOCHS':5,
#     'LEARNING_RATE':1e-4,
#     'BATCH_SIZE':16,
#     'SEED':41
# }

# %% [markdown]
# # 4. Paths

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1Fhm4QNmL9YBtKMyDw3aIOwh8OmGf0zvZ/데이콘

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CAKD7/데이콘
# Out:
# /content/drive/.shortcut-targets-by-id/1Fhm4QNmL9YBtKMyDw3aIOwh8OmGf0zvZ/데이콘

# %%
# base_skin_dir = os.path.join('..', 'input')
#Dictionary for Image Names

base_skin_dir = '/content/drive/MyDrive/CAKD7/데이콘'

#imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join(base_skin_dir, '*','*', '*.jpg'))}

# %% [markdown]
# # 5. Dataset
# # 5.1 Description

# %% [markdown]
# The data set contains the following diseases:
# - Actinic Keratosis
# - Basal Cell Carcinoma
# - Dermatofibroma
# - Melanoma
# - Nevus
# - Pigmented Benign Keratosis
# - Vascular Lesion

# %%
# df = pd.read_csv('../input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
# df = pd.read_pickle(f"../input/skin-cancer-mnist-ham10000-pickle/HAM10000_metadata-h{CFG['img_height']}-w{CFG['img_width']}.pkl")
# df.head()

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df[:5]
# Out:
#            ID                     img_path mask_path  나이       수술연월일  진단명  \
# 0  BC_01_0001  ./train_imgs/BC_01_0001.png         -  63  2015-10-23    1
# 1  BC_01_0002  ./train_imgs/BC_01_0002.png         -  51  2015-10-28    1
# 2  BC_01_0003  ./train_imgs/BC_01_0003.png         -  37  2015-10-29    1
# 3  BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 4  BC_01_0005  ./train_imgs/BC_01_0005.png         -  57  2015-10-30    1
#
#    암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 0      2      1   19.0  2.0  ...              8.0  1.0              6.0
# 1      1      1   22.0  3.0  ...              NaN  0.0              NaN
# 2      2      1    NaN  2.0  ...              7.0  1.0              4.0
# 3      2      1    0.0  3.0  ...              NaN  0.0              NaN
# 4      2      1    8.0  2.0  ...              8.0  0.0              NaN
#
#    KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 0              12.0   0.0       1.0        NaN              NaN
# 1              70.0   0.0       0.0        NaN              NaN
# 2               7.0   0.0       1.0        NaN              NaN
# 3               1.0   1.0       3.0        NaN              NaN
# 4               8.0   1.0       2.0        1.0             5.44
#
#    BRCA_mutation  N_category
# 0            NaN           0
# 1            NaN           1
# 2            0.0           0
# 3            NaN           0
# 4            NaN           0
#
# [5 rows x 28 columns]

# %%
train_df['암의 장경'] = train_df['암의 장경'].fillna(train_df['암의 장경'].mean())
train_df = train_df.fillna(0)

test_df['암의 장경'] = test_df['암의 장경'].fillna(train_df['암의 장경'].mean())
test_df = test_df.fillna(0)

# %%
train_df, val_df, train_labels, val_labels = train_test_split(
                                                    train_df.drop(columns=['N_category']), 
                                                    train_df['N_category'], 
                                                    test_size=0.2, 
                                                    random_state=CFG['SEED']
                                                )

# %%
def get_values(value):
    return value.values.reshape(-1, 1)

numeric_cols = ['나이', '암의 장경', 'ER_Allred_score', 'PR_Allred_score', 'KI-67_LI_percent', 'HER2_SISH_ratio']
ignore_cols = ['ID', 'img_path', 'mask_path', '수술연월일', 'N_category']

for col in train_df.columns:
    if col in ignore_cols:
        continue
    if col in numeric_cols:
        scaler = StandardScaler()
        train_df[col] = scaler.fit_transform(get_values(train_df[col]))
        val_df[col] = scaler.transform(get_values(val_df[col]))
        test_df[col] = scaler.transform(get_values(test_df[col]))
    else:
        le = LabelEncoder()
        train_df[col] = le.fit_transform(get_values(train_df[col]))
        val_df[col] = le.transform(get_values(val_df[col]))
        test_df[col] = le.transform(get_values(test_df[col]))

# %%
class CustomDataset(Dataset):
    def __init__(self, medical_df, labels, transforms=None):
        self.medical_df = medical_df
        self.transforms = transforms
        self.labels = labels
        
    def __getitem__(self, index):
        img_path = self.medical_df['img_path'].iloc[index]
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        if self.transforms is not None:
            image = self.transforms(image=image)['image']
                
        if self.labels is not None:
            tabular = torch.Tensor(self.medical_df.drop(columns=['ID', 'img_path', 'mask_path', '수술연월일']).iloc[index])
            label = self.labels[index]
            return image, tabular, label
        else:
            tabular = torch.Tensor(self.medical_df.drop(columns=['ID', 'img_path', '수술연월일']).iloc[index])
            return image, tabular
        
    def __len__(self):
        return len(self.medical_df)

# %%
# # Given lesion types
# classes = df.dx.unique()
# num_classes = len(classes)
# classes, num_classes
# Out:
# (array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object), 7)

# %%
#Lesion Dictionary created for ease
# lesion_type_dict = {
#     'bkl'  : 'Pigmented Benign keratosis',
#     'nv'   : 'Melanocytic nevi', # nevus
#     'df'   : 'Dermatofibroma',
#     'mel'  : 'Melanoma',
#     'vasc' : 'Vascular lesions',
#     'bcc'  : 'Basal cell carcinoma',
#     'akiec': 'Actinic keratoses',
# }

# %%
# Not required for pickled data
# Creating New Columns for better readability

# df['num_images'] = df.groupby('lesion_id')["image_id"].transform("count")
# df['path'] = df.image_id.map(imageid_path_dict.get)
# df['cell_type'] = df.dx.map(lesion_type_dict.get) 
# df['cell_type_idx'] = pd.Categorical(df.dx).codes
# df.sample(5)
# Out:
#         lesion_id      image_id     dx    dx_type   age     sex  \
# 9725  HAM_0004376  ISIC_0024843  akiec      histo  70.0  female
# 6059  HAM_0003024  ISIC_0024768     nv  follow_up  35.0  female
# 4540  HAM_0001659  ISIC_0026564     nv  follow_up  35.0    male
# 3817  HAM_0004625  ISIC_0029346     nv  follow_up  40.0    male
# 7914  HAM_0000443  ISIC_0034271     nv      histo  35.0  female
#
#          localization  num_images  \
# 9725             face           1
# 6059            trunk           1
# 4540  lower extremity           1
# 3817  upper extremity           1
# 7914             back           1
#
#                                                    path          cell_type  \
# 9725  ../input/skin-cancer-mnist-ham10000/ham10000_i...  Actinic keratoses
# 6059  ../input/skin-cancer-mnist-ham10000/ham10000_i...   Melanocytic nevi
# 4540  ../input/skin-cancer-mnist-ham10000/ham10000_i...   Melanocytic nevi
# 3817  ../input/skin-cancer-mnist-ham10000/ham10000_i...   Melanocytic nevi
# 7914  ../input/skin-cancer-mnist-ham10000/ham10000_i...   Melanocytic nevi
#
#       cell_type_idx
# 9725              0
# 6059              5
# 4540              5
# 3817              5
# 7914              5

# %% [markdown]
# # 5.2 Exploratory Data Analysis x 안함

# %%
df.shape
# Out:
# (10015, 11)

# %%
df.isnull().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# num_images        0
# path              0
# cell_type         0
# cell_type_idx     0
# dtype: int64

# %%
df.age.fillna((df.age.mean()), inplace=True)
df.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age              0
# sex              0
# localization     0
# num_images       0
# path             0
# cell_type        0
# cell_type_idx    0
# dtype: int64

# %% [markdown]
# # 6. Keras image data processing

# %%
# Not required for pickled data
# df['image'] = df.path.map(lambda x: np.asarray(Image.open(x).resize((CFG['img_width'], CFG['img_height']))))
# df.to_pickle(f"HAM10000_metadata-h{CFG['img_height']}-w{CFG['img_width']}.pkl", compression='infer', protocol=4)

# %%
train_df['image'] = train_df.img_path.map(lambda x: np.asarray(Image.open(x).resize((CFG['img_width'], CFG['img_height']))))
test_df['image'] = test_df.img_path.map(lambda x: np.asarray(Image.open(x).resize((CFG['img_width'], CFG['img_height']))))

# %%
train_df.to_pickle('train_df.pkl')
test_df.to_pickle('test_df.pkl')

# %%
# df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#    num_images                                               path  \
# 0           2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 1           2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 2           2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 3           2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 4           2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
#
#                     cell_type  cell_type_idx  \
# 0  Pigmented Benign keratosis              2
# 1  Pigmented Benign keratosis              2
# 2  Pigmented Benign keratosis              2
# 3  Pigmented Benign keratosis              2
# 4  Pigmented Benign keratosis              2
#
#                                                image
# 0  [[[188, 151, 193], [193, 156, 198], [192, 155,...
# 1  [[[24, 13, 22], [24, 13, 22], [24, 14, 25], [2...
# 2  [[[186, 126, 135], [189, 131, 142], [192, 136,...
# 3  [[[23, 11, 16], [24, 11, 19], [26, 13, 22], [3...
# 4  [[[129, 87, 109], [139, 94, 117], [148, 102, 1...

# %%
def prepareimages(images):
    # images is a list of images
    images = np.asarray(images).astype(np.float64)
    images = images[:, :, :, ::-1]
    m0 = np.mean(images[:, :, :, 0])
    m1 = np.mean(images[:, :, :, 1])
    m2 = np.mean(images[:, :, :, 2])
    images[:, :, :, 0] -= m0
    images[:, :, :, 1] -= m1
    images[:, :, :, 2] -= m2
    return images

df_single = df[df.num_images == 1]
trainset1, testset = train_test_split(df_single, test_size=0.2,random_state = 80)
trainset2, validationset = train_test_split(trainset1, test_size=0.2,random_state = 600)
trainset3 = df[df.num_images != 1]
trainset = pd.concat([trainset2, trainset3])

trainimages = prepareimages(list(trainset.image))
testimages = prepareimages(list(testset.image))
validationimages = prepareimages(list(validationset.image))
trainlabels = np.asarray(trainset.cell_type_idx)
testlabels = np.asarray(testset.cell_type_idx)
validationlabels = np.asarray(validationset.cell_type_idx)

# %%
image_shape = (CFG['img_height'], CFG['img_width'], 3)

trainimages = trainimages.reshape(trainimages.shape[0], *image_shape)

data_gen = ImageDataGenerator(
    rotation_range = CFG['ROTATION_RANGE'],    # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = CFG['ZOOM_RANGE'],            # Randomly zoom image 
    width_shift_range = CFG['WSHIFT_RANGE'],   # randomly shift images horizontally
    height_shift_range = CFG['HSHIFT_RANGE'],  # randomly shift images vertically
    horizontal_flip=CFG['HFLIP'],              # randomly flip images
    vertical_flip=CFG['VFLIP']                 # randomly flip images
)
data_gen.fit(trainimages)

# %% [markdown]
# # 7. Model

# %% [markdown]
# # 7.1 Build the model

# %%
def build_model(
    base_model,
    base_model_name,
    model_optimizer,
    raw_model = False,
    last_trainable_layers = CFG['last_trainable_layers'],
    model_loss = 'sparse_categorical_crossentropy'
):
    print(f'Building {base_model_name} model...')

    # We reduce significantly number of trainable parameters by freezing certain layers,
    # excluding from training, i.e. their weights will never be updated
    for layer in base_model.layers:
        layer.trainable = False

    if 0 < last_trainable_layers < len(base_model.layers):
        for layer in base_model.layers[-last_trainable_layers:]:
            layer.trainable = True

    if raw_model == True:
        model = base_model
    else:
        model = Sequential([
            base_model,

            Dropout(0.5),
            Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.02)),

            Dropout(0.5),
            Dense(num_classes, activation='softmax', kernel_regularizer=regularizers.l2(0.02)) # num classes = 9
        ])

    model.compile(
        optimizer = model_optimizer,
      # loss = tf.keras.losses.BinaryCrossentropy(label_smoothing = CFG['label_smooth_fac']),
        loss = model_loss,
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# # 7.2 Visualize model

# %%
def visualize_model(model, model_name):
    print(model.summary())
    return plot_model(model, to_file=f'{model_name}_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # 8. Fit model

# %%
class GCCollectCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()

# %%
def fit_model(
    model,
    model_name,
    trainimages,
    trainlabels,
    validationimages,
    validationlabels,
    early_stopper_patience = CFG['stopper_patience'],
    epochs = CFG['epochs'],
    batch_size = CFG['batch_size']
):
    # tf.function - decorated function tried to create variables on non-first call'. 
    tf.config.run_functions_eagerly(CFG['run_functions_eagerly']) # otherwise error

    print(f'Fitting {model_name} model...')
    # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
    cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = early_stopper_patience)
    cb_checkpointer  = ModelCheckpoint(
        filepath=f'model/{model_name}.hdf5',
      # filepath = CFG['path_model']+'ResNet50-{epoch:02d}-{val_loss:.2f}.hdf5',
        monitor  = 'val_loss',
        save_best_only=True, 
        mode='min'
    )

    callbacks_list = [cb_checkpointer, cb_early_stopper]

    history = model.fit(
        data_gen.flow(trainimages, trainlabels, batch_size = batch_size),
        epochs = epochs,
        validation_data = data_gen.flow(validationimages, validationlabels, batch_size = batch_size),
        verbose = CFG['verbose'],
        steps_per_epoch=trainimages.shape[0] // batch_size,                   
        callbacks=[cb_checkpointer, cb_early_stopper] # We can add GCCollectCallback() to save memory
    )

    return history

# %% [markdown]
# # 9. Visualize performance

# %%
def visualize_performance(model_name, history, fontsize = CFG['fontsize']):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    metrics = history.history['accuracy']
    epochs_range = range(1, len(metrics) + 1) 

    plt.figure(figsize=(23, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.suptitle(f'Accuracy & Loss for {model_name} model', fontsize=fontsize)
    plt.show()

# %% [markdown]
# # 10. Evaluate on test

# %%
def evaluate_model(
    model_name,
    trainimages,
    trainlabels,
    validationimages,
    validationlabels,
    testimages,
    testlabels
):
    print(f'Evaluating {model_name} model...\n')
    model = load_model(f'./model/{model_name}.hdf5') # Loads the best fit model

    print("Train loss = {}  ;  Train accuracy = {:.2%}\n".format(*model.evaluate(trainimages, trainlabels, verbose = CFG['verbose'])))

    print("Validation loss = {}  ;  Validation accuracy = {:.2%}\n".format(*model.evaluate(validationimages, validationlabels, verbose = CFG['verbose'])))

    test_loss, test_acc = model.evaluate(testimages, testlabels, verbose = CFG['verbose'])
    print(f"Test loss = {test_loss}  ;  Test accuracy = {test_acc:.2%}")

    return (model, test_loss, test_acc)

# %%
def computing_prediction(model, model_name, trainimages, testimages):
    print(f'Computing predictions for {model_name}...')
    train_pred = model.predict(trainimages)
    train_pred_classes = np.argmax(train_pred,axis = 1)
    test_pred = model.predict(testimages)
    # Convert predictions classes to one hot vectors
    test_pred_classes = np.argmax(test_pred,axis = 1)

    return train_pred, train_pred_classes, test_pred, test_pred_classes

# %% [markdown]
# # 11. Compare test_pred with Ground Truth (train_pred)

# %%
def model_report(
    model_name,
    trainlabels,
    train_pred_classes,
    testlabels,
    test_pred_classes,
    lesion_type_dict,
    fontsize = CFG['fontsize']
):
    print(f'Model report for {model_name} model ->\n\n')
    print("Train Report :\n", classification_report(trainlabels, train_pred_classes, target_names=lesion_type_dict.values()))
    print("Test Report :\n", classification_report(testlabels, test_pred_classes, target_names=lesion_type_dict.values()))

    cm = confusion_matrix(testlabels, test_pred_classes)

    fig = plt.figure(figsize=(12, 8))
    df_cm = pd.DataFrame(cm, index=lesion_type_dict.values(), columns=lesion_type_dict.values())

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, cmap='Blues')
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")

    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label', fontsize=fontsize)
    plt.xlabel('Predicted label', fontsize=fontsize)

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.title(f'Confusion Matrix for Multiclass Classifcation ({model_name})', fontsize=fontsize)
    plt.show()

# %% [markdown]
# # 12. ResNet50 model

# %%
ResNet50_name = 'ResNet50'

# %%
resnet50 = ResNet50(
    include_top=False,
    input_shape=image_shape,
    pooling = 'avg',
    weights='imagenet'
)

Resnet50_model = build_model(
    base_model = resnet50,
    base_model_name = ResNet50_name,
    model_optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# 94781440/94765736 [==============================] - 2s 0us/step
# Building ResNet50 model...

# %%
visualize_model(model = Resnet50_model, model_name = ResNet50_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 23,850,887
# Trainable params: 263,175
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None

# %%
history = fit_model(    
    model = Resnet50_model,
    model_name = ResNet50_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels
)
# Out:
# Fitting ResNet50 model...
# Epoch 1/30
# 401/401 [==============================] - 55s 107ms/step - loss: 5.8866 - accuracy: 0.5579 - val_loss: 4.4009 - val_accuracy: 0.8029
# Epoch 2/30
# 401/401 [==============================] - 42s 105ms/step - loss: 4.2208 - accuracy: 0.6312 - val_loss: 3.3852 - val_accuracy: 0.8211
# Epoch 3/30
# 401/401 [==============================] - 41s 103ms/step - loss: 3.3271 - accuracy: 0.6446 - val_loss: 2.6975 - val_accuracy: 0.8347
# Epoch 4/30
# 401/401 [==============================] - 43s 107ms/step - loss: 2.6978 - accuracy: 0.6614 - val_loss: 2.1438 - val_accuracy: 0.8381
# Epoch 5/30
# 401/401 [==============================] - 41s 102ms/step - loss: 2.2743 - accuracy: 0.6720 - val_loss: 1.7844 - val_accuracy: 0.8369
# Epoch 6/30
# 401/401 [==============================] - 43s 106ms/step - loss: 1.9515 - accuracy: 0.6802 - val_loss: 1.5505 - val_accuracy: 0.8335
# Epoch 7/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.7315 - accuracy: 0.6876 - val_loss: 1.3414 - val_accuracy: 0.8426
# Epoch 8/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.5686 - accuracy: 0.6896 - val_loss: 1.1555 - val_accuracy: 0.8381
# Epoch 9/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.4316 - accuracy: 0.6972 - val_loss: 1.0637 - val_accuracy: 0.8437
# Epoch 10/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.3200 - accuracy: 0.6972 - val_loss: 0.9500 - val_accuracy: 0.8437
# Epoch 11/30
# 401/401 [==============================] - 42s 103ms/step - loss: 1.2634 - accuracy: 0.6995 - val_loss: 0.9239 - val_accuracy: 0.8482
# Epoch 12/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.2007 - accuracy: 0.7026 - val_loss: 0.8605 - val_accuracy: 0.8392
# Epoch 13/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.1431 - accuracy: 0.7055 - val_loss: 0.7788 - val_accuracy: 0.8539
# Epoch 14/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.0975 - accuracy: 0.7097 - val_loss: 0.7571 - val_accuracy: 0.8528
# Epoch 15/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.0665 - accuracy: 0.7081 - val_loss: 0.7484 - val_accuracy: 0.8494
# Epoch 16/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.0375 - accuracy: 0.7158 - val_loss: 0.7371 - val_accuracy: 0.8596
# Epoch 17/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.0134 - accuracy: 0.7241 - val_loss: 0.6693 - val_accuracy: 0.8471
# Epoch 18/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.0003 - accuracy: 0.7169 - val_loss: 0.6537 - val_accuracy: 0.8494
# Epoch 19/30
# 401/401 [==============================] - 43s 106ms/step - loss: 0.9837 - accuracy: 0.7193 - val_loss: 0.6743 - val_accuracy: 0.8596
# Epoch 20/30
# 401/401 [==============================] - 43s 106ms/step - loss: 0.9711 - accuracy: 0.7171 - val_loss: 0.6498 - val_accuracy: 0.8516
# Epoch 21/30
# 401/401 [==============================] - 41s 102ms/step - loss: 0.9576 - accuracy: 0.7203 - val_loss: 0.6449 - val_accuracy: 0.8516
# Epoch 22/30
# 401/401 [==============================] - 43s 106ms/step - loss: 0.9400 - accuracy: 0.7264 - val_loss: 0.6483 - val_accuracy: 0.8448
# Epoch 23/30
# 401/401 [==============================] - 41s 102ms/step - loss: 0.9388 - accuracy: 0.7219 - val_loss: 0.6274 - val_accuracy: 0.8573
# Epoch 24/30
# 401/401 [==============================] - 41s 101ms/step - loss: 0.9306 - accuracy: 0.7234 - val_loss: 0.6436 - val_accuracy: 0.8505
# Epoch 25/30
# 401/401 [==============================] - 42s 105ms/step - loss: 0.9285 - accuracy: 0.7197 - val_loss: 0.6127 - val_accuracy: 0.8584
# Epoch 26/30
# 401/401 [==============================] - 41s 102ms/step - loss: 0.9076 - accuracy: 0.7266 - val_loss: 0.5850 - val_accuracy: 0.8573
# Epoch 27/30
# 401/401 [==============================] - 42s 106ms/step - loss: 0.9173 - accuracy: 0.7233 - val_loss: 0.6027 - val_accuracy: 0.8494
# Epoch 28/30
# 401/401 [==============================] - 41s 102ms/step - loss: 0.8981 - accuracy: 0.7297 - val_loss: 0.6074 - val_accuracy: 0.8584
# Epoch 29/30
# 401/401 [==============================] - 42s 105ms/step - loss: 0.9023 - accuracy: 0.7251 - val_loss: 0.5911 - val_accuracy: 0.8437
# Epoch 30/30
# 401/401 [==============================] - 42s 106ms/step - loss: 0.9010 - accuracy: 0.7218 - val_loss: 0.5967 - val_accuracy: 0.8437

# %%
visualize_performance(
    model_name = ResNet50_name,
    history = history
)

# %%
Resnet50_model, test_loss, ResNet50_test_acc = evaluate_model(
    model_name = ResNet50_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels,
    testimages = testimages,
    testlabels = testlabels
)
# Out:
# Evaluating ResNet50 model...
#
# 251/251 [==============================] - 9s 33ms/step - loss: 0.8491 - accuracy: 0.7382
# Train loss = 0.8491464853286743  ;  Train accuracy = 73.82%
#
# 28/28 [==============================] - 1s 30ms/step - loss: 0.5863 - accuracy: 0.8516
# Validation loss = 0.5863086581230164  ;  Validation accuracy = 85.16%
#
# 35/35 [==============================] - 1s 29ms/step - loss: 0.5777 - accuracy: 0.8640
# Test loss = 0.5776748061180115  ;  Test accuracy = 86.40%

# %%
train_pred, train_pred_classes, test_pred, test_pred_classes = computing_prediction(
    model = Resnet50_model,
    model_name = ResNet50_name,
    trainimages = trainimages,
    testimages = testimages
)

test_pred, test_pred_classes
# Out:
# Computing predictions for ResNet50...
# (array([[8.7999681e-05, 2.1303855e-04, 6.5205526e-04, ..., 1.3347293e-03,
#          9.9719185e-01, 3.4722924e-04],
#         [7.8174435e-03, 2.3866624e-02, 2.1124335e-02, ..., 1.1570640e-02,
#          9.0359861e-01, 2.2468414e-02],
#         [3.6852004e-04, 2.2553187e-04, 4.9255737e-03, ..., 4.2572501e-03,
#          9.8993999e-01, 2.9653793e-05],
#         ...,
#         [2.7573332e-03, 3.3063046e-03, 1.3148531e-02, ..., 2.1908566e-02,
#          9.5682925e-01, 3.8492904e-04],
#         [6.6478825e-03, 1.0804347e-02, 1.3011480e-02, ..., 7.7116541e-03,
#          9.4949812e-01, 3.5965254e-03],
#         [7.5301319e-02, 3.4539154e-01, 3.4370017e-01, ..., 2.6790092e-02,
#          1.6756666e-01, 1.4404633e-02]], dtype=float32),
#  array([5, 5, 5, ..., 5, 5, 1]))

# %%
model_report(
    model_name = ResNet50_name,
    trainlabels = trainlabels,
    train_pred_classes = train_pred_classes,
    testlabels = testlabels,
    test_pred_classes = test_pred_classes,
    lesion_type_dict = lesion_type_dict
)
# Out:
# Model report for ResNet50 model ->
#
#
# Train Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.89      0.09      0.16       264
#           Melanocytic nevi       0.50      0.63      0.55       452
#             Dermatofibroma       0.59      0.40      0.48       945
#                   Melanoma       0.00      0.00      0.00       101
#           Vascular lesions       0.70      0.20      0.31      1029
#       Basal cell carcinoma       0.77      0.98      0.86      5110
#          Actinic keratoses       0.96      0.35      0.51       128
#
#                   accuracy                           0.74      8029
#                  macro avg       0.63      0.38      0.41      8029
#               weighted avg       0.72      0.74      0.69      8029
#
# Test Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       1.00      0.03      0.06        32
#           Melanocytic nevi       0.49      0.54      0.51        35
#             Dermatofibroma       0.51      0.60      0.55        84
#                   Melanoma       0.00      0.00      0.00        10
#           Vascular lesions       0.40      0.06      0.10        35
#       Basal cell carcinoma       0.92      0.98      0.95       895
#          Actinic keratoses       1.00      0.33      0.50        12
#
#                   accuracy                           0.86      1103
#                  macro avg       0.62      0.36      0.38      1103
#               weighted avg       0.85      0.86      0.84      1103

# %% [markdown]
# # 13. InceptionV3 model

# %%
InceptionV3_name = 'InceptionV3'

# %%
inceptionv3 = InceptionV3(
    include_top=False,
    input_shape=image_shape,
    pooling = 'avg',
    weights='imagenet'
)

InceptionV3_model = build_model(
    base_model = inceptionv3,
    base_model_name = InceptionV3_name,
    model_optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)
)
# Out:
# Building InceptionV3 model...

# %%
visualize_model(model = InceptionV3_model, model_name = InceptionV3_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 2048)              21802784
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 22,065,959
# Trainable params: 263,175
# Non-trainable params: 21,802,784
# _________________________________________________________________
# None

# %%
history = fit_model(    
    model = InceptionV3_model,
    model_name = InceptionV3_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels
)
# Out:
# Fitting InceptionV3 model...
# Epoch 1/30
# 401/401 [==============================] - 52s 112ms/step - loss: 19.6025 - accuracy: 0.4281 - val_loss: 6.7694 - val_accuracy: 0.6580
# Epoch 2/30
# 401/401 [==============================] - 43s 106ms/step - loss: 7.6434 - accuracy: 0.5024 - val_loss: 6.6410 - val_accuracy: 0.7928
# Epoch 3/30
# 401/401 [==============================] - 42s 105ms/step - loss: 6.8072 - accuracy: 0.5865 - val_loss: 6.4496 - val_accuracy: 0.7928
# Epoch 4/30
# 401/401 [==============================] - 43s 107ms/step - loss: 6.5318 - accuracy: 0.6059 - val_loss: 5.9641 - val_accuracy: 0.7928
# Epoch 5/30
# 401/401 [==============================] - 42s 106ms/step - loss: 6.1933 - accuracy: 0.6206 - val_loss: 5.4725 - val_accuracy: 0.7928
# Epoch 6/30
# 401/401 [==============================] - 42s 105ms/step - loss: 5.9586 - accuracy: 0.6258 - val_loss: 5.3224 - val_accuracy: 0.7928
# Epoch 7/30
# 401/401 [==============================] - 43s 108ms/step - loss: 5.6173 - accuracy: 0.6289 - val_loss: 5.0338 - val_accuracy: 0.7928
# Epoch 8/30
# 401/401 [==============================] - 44s 109ms/step - loss: 5.3356 - accuracy: 0.6318 - val_loss: 4.7562 - val_accuracy: 0.7928
# Epoch 9/30
# 401/401 [==============================] - 43s 106ms/step - loss: 4.9855 - accuracy: 0.6335 - val_loss: 4.4519 - val_accuracy: 0.7928
# Epoch 10/30
# 401/401 [==============================] - 42s 104ms/step - loss: 4.6992 - accuracy: 0.6332 - val_loss: 4.0568 - val_accuracy: 0.7928
# Epoch 11/30
# 401/401 [==============================] - 42s 105ms/step - loss: 4.3544 - accuracy: 0.6347 - val_loss: 3.7927 - val_accuracy: 0.7928
# Epoch 12/30
# 401/401 [==============================] - 42s 104ms/step - loss: 3.9924 - accuracy: 0.6327 - val_loss: 3.4478 - val_accuracy: 0.7928
# Epoch 13/30
# 401/401 [==============================] - 42s 104ms/step - loss: 3.6919 - accuracy: 0.6339 - val_loss: 3.1463 - val_accuracy: 0.7928
# Epoch 14/30
# 401/401 [==============================] - 42s 104ms/step - loss: 3.3754 - accuracy: 0.6352 - val_loss: 2.8921 - val_accuracy: 0.7928
# Epoch 15/30
# 401/401 [==============================] - 41s 103ms/step - loss: 3.0965 - accuracy: 0.6338 - val_loss: 2.5950 - val_accuracy: 0.7928
# Epoch 16/30
# 401/401 [==============================] - 43s 106ms/step - loss: 2.8395 - accuracy: 0.6350 - val_loss: 2.3137 - val_accuracy: 0.7928
# Epoch 17/30
# 401/401 [==============================] - 41s 103ms/step - loss: 2.5928 - accuracy: 0.6344 - val_loss: 2.0902 - val_accuracy: 0.7928
# Epoch 18/30
# 401/401 [==============================] - 42s 104ms/step - loss: 2.3454 - accuracy: 0.6353 - val_loss: 1.8433 - val_accuracy: 0.7928
# Epoch 19/30
# 401/401 [==============================] - 42s 105ms/step - loss: 2.1471 - accuracy: 0.6348 - val_loss: 1.6719 - val_accuracy: 0.7928
# Epoch 20/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.9886 - accuracy: 0.6342 - val_loss: 1.5709 - val_accuracy: 0.7928
# Epoch 21/30
# 401/401 [==============================] - 43s 106ms/step - loss: 1.8784 - accuracy: 0.6349 - val_loss: 1.4248 - val_accuracy: 0.7928
# Epoch 22/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.7650 - accuracy: 0.6347 - val_loss: 1.3129 - val_accuracy: 0.7928
# Epoch 23/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.6735 - accuracy: 0.6350 - val_loss: 1.2760 - val_accuracy: 0.7928
# Epoch 24/30
# 401/401 [==============================] - 43s 107ms/step - loss: 1.6121 - accuracy: 0.6349 - val_loss: 1.1804 - val_accuracy: 0.7928
# Epoch 25/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.5542 - accuracy: 0.6343 - val_loss: 1.1469 - val_accuracy: 0.7928
# Epoch 26/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.4886 - accuracy: 0.6382 - val_loss: 1.0776 - val_accuracy: 0.7984
# Epoch 27/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.4350 - accuracy: 0.6378 - val_loss: 1.0309 - val_accuracy: 0.7928
# Epoch 28/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.3806 - accuracy: 0.6430 - val_loss: 1.0200 - val_accuracy: 0.7973
# Epoch 29/30
# 401/401 [==============================] - 44s 109ms/step - loss: 1.3412 - accuracy: 0.6446 - val_loss: 0.9721 - val_accuracy: 0.8041
# Epoch 30/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.3072 - accuracy: 0.6456 - val_loss: 0.9281 - val_accuracy: 0.8052

# %%
visualize_performance(
    model_name = InceptionV3_name,
    history = history
)

# %%
InceptionV3_model, test_loss, InceptionV3_test_acc = evaluate_model(
    model_name = InceptionV3_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels,
    testimages = testimages,
    testlabels = testlabels
)
# Out:
# Evaluating InceptionV3 model...
#
# 251/251 [==============================] - 18s 33ms/step - loss: 1.1926 - accuracy: 0.6541
# Train loss = 1.1926130056381226  ;  Train accuracy = 65.41%
#
# 28/28 [==============================] - 1s 41ms/step - loss: 0.9246 - accuracy: 0.8075
# Validation loss = 0.9245985150337219  ;  Validation accuracy = 80.75%
#
# 35/35 [==============================] - 2s 42ms/step - loss: 0.9345 - accuracy: 0.8241
# Test loss = 0.934461772441864  ;  Test accuracy = 82.41%

# %%
train_pred, train_pred_classes, test_pred, test_pred_classes = computing_prediction(
    model = InceptionV3_model,
    model_name = InceptionV3_name,
    trainimages = trainimages,
    testimages = testimages
)

test_pred, test_pred_classes
# Out:
# Computing predictions for InceptionV3...
# (array([[1.18222542e-05, 1.02163222e-05, 1.87052488e-02, ...,
#          1.12695791e-01, 8.61275554e-01, 7.30094314e-03],
#         [7.49734864e-02, 1.06543265e-01, 1.48987249e-01, ...,
#          1.23663433e-01, 4.17557985e-01, 6.90397695e-02],
#         [5.54622710e-03, 1.89800672e-02, 1.21879704e-01, ...,
#          1.55999854e-01, 6.62822723e-01, 3.14010456e-02],
#         ...,
#         [1.07226223e-02, 2.16721464e-02, 1.36557788e-01, ...,
#          1.54399022e-01, 6.24557257e-01, 4.63151708e-02],
#         [3.31545733e-02, 6.99570104e-02, 1.54075608e-01, ...,
#          1.52383342e-01, 5.24760425e-01, 4.47074808e-02],
#         [5.08631729e-02, 8.72490630e-02, 1.49193719e-01, ...,
#          1.34800524e-01, 4.77229685e-01, 6.18899465e-02]], dtype=float32),
#  array([5, 5, 5, ..., 5, 5, 5]))

# %%
model_report(
    model_name = InceptionV3_name,
    trainlabels = trainlabels,
    train_pred_classes = train_pred_classes,
    testlabels = testlabels,
    test_pred_classes = test_pred_classes,
    lesion_type_dict = lesion_type_dict
)
# Out:
# Model report for InceptionV3 model ->
#
#
# Train Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.00      0.00      0.00       264
#           Melanocytic nevi       0.45      0.14      0.22       452
#             Dermatofibroma       0.37      0.16      0.22       945
#                   Melanoma       0.00      0.00      0.00       101
#           Vascular lesions       1.00      0.00      0.01      1029
#       Basal cell carcinoma       0.67      0.99      0.80      5110
#          Actinic keratoses       0.00      0.00      0.00       128
#
#                   accuracy                           0.65      8029
#                  macro avg       0.36      0.18      0.18      8029
#               weighted avg       0.63      0.65      0.55      8029
#
# Test Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.00      0.00      0.00        32
#           Melanocytic nevi       0.50      0.20      0.29        35
#             Dermatofibroma       0.45      0.20      0.28        84
#                   Melanoma       0.00      0.00      0.00        10
#           Vascular lesions       0.00      0.00      0.00        35
#       Basal cell carcinoma       0.84      0.99      0.91       895
#          Actinic keratoses       0.00      0.00      0.00        12
#
#                   accuracy                           0.82      1103
#                  macro avg       0.26      0.20      0.21      1103
#               weighted avg       0.73      0.82      0.77      1103

# %% [markdown]
# # 14. VGG-16 model

# %%
VGG16_name = 'VGG-16'

# %%
vgg16 = VGG16(
    include_top=False,
    input_shape=image_shape,
    pooling = 'avg',
    weights='imagenet'
)

VGG16_model = build_model(
    base_model = vgg16,
    base_model_name = VGG16_name,
    model_optimizer = RMSprop(lr=0.0001, epsilon=None, decay=1e-6)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Building VGG-16 model...

# %%
visualize_model(model = VGG16_model, model_name = VGG16_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 14,781,255
# Trainable params: 66,567
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
history = fit_model(    
    model = VGG16_model,
    model_name = VGG16_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels
)
# Out:
# Fitting VGG-16 model...
# Epoch 1/30
# 401/401 [==============================] - 45s 107ms/step - loss: 9.9036 - accuracy: 0.4259 - val_loss: 4.7456 - val_accuracy: 0.7939
# Epoch 2/30
# 401/401 [==============================] - 42s 104ms/step - loss: 6.5631 - accuracy: 0.5172 - val_loss: 3.7889 - val_accuracy: 0.7995
# Epoch 3/30
# 401/401 [==============================] - 42s 104ms/step - loss: 4.9769 - accuracy: 0.5434 - val_loss: 3.2472 - val_accuracy: 0.8131
# Epoch 4/30
# 401/401 [==============================] - 42s 104ms/step - loss: 3.9229 - accuracy: 0.5690 - val_loss: 2.8391 - val_accuracy: 0.8120
# Epoch 5/30
# 401/401 [==============================] - 41s 101ms/step - loss: 3.2160 - accuracy: 0.5937 - val_loss: 2.4156 - val_accuracy: 0.7984
# Epoch 6/30
# 401/401 [==============================] - 42s 105ms/step - loss: 2.7580 - accuracy: 0.6008 - val_loss: 2.1580 - val_accuracy: 0.8256
# Epoch 7/30
# 401/401 [==============================] - 42s 104ms/step - loss: 2.3921 - accuracy: 0.6101 - val_loss: 1.8985 - val_accuracy: 0.8131
# Epoch 8/30
# 401/401 [==============================] - 41s 101ms/step - loss: 2.1316 - accuracy: 0.6183 - val_loss: 1.6861 - val_accuracy: 0.8143
# Epoch 9/30
# 401/401 [==============================] - 42s 104ms/step - loss: 1.9351 - accuracy: 0.6278 - val_loss: 1.5366 - val_accuracy: 0.8245
# Epoch 10/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.7950 - accuracy: 0.6330 - val_loss: 1.4419 - val_accuracy: 0.8290
# Epoch 11/30
# 401/401 [==============================] - 41s 101ms/step - loss: 1.6667 - accuracy: 0.6394 - val_loss: 1.3613 - val_accuracy: 0.8188
# Epoch 12/30
# 401/401 [==============================] - 40s 101ms/step - loss: 1.5753 - accuracy: 0.6387 - val_loss: 1.2317 - val_accuracy: 0.8143
# Epoch 13/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.5047 - accuracy: 0.6483 - val_loss: 1.1776 - val_accuracy: 0.8301
# Epoch 14/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.4260 - accuracy: 0.6493 - val_loss: 1.1344 - val_accuracy: 0.8358
# Epoch 15/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.3851 - accuracy: 0.6580 - val_loss: 1.0409 - val_accuracy: 0.8267
# Epoch 16/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.3342 - accuracy: 0.6545 - val_loss: 1.0132 - val_accuracy: 0.8233
# Epoch 17/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.2966 - accuracy: 0.6581 - val_loss: 1.0012 - val_accuracy: 0.8335
# Epoch 18/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.2683 - accuracy: 0.6616 - val_loss: 0.9420 - val_accuracy: 0.8301
# Epoch 19/30
# 401/401 [==============================] - 41s 101ms/step - loss: 1.2272 - accuracy: 0.6666 - val_loss: 0.9251 - val_accuracy: 0.8324
# Epoch 20/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.2099 - accuracy: 0.6661 - val_loss: 0.8782 - val_accuracy: 0.8448
# Epoch 21/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.1942 - accuracy: 0.6624 - val_loss: 0.8597 - val_accuracy: 0.8414
# Epoch 22/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.1615 - accuracy: 0.6705 - val_loss: 0.8247 - val_accuracy: 0.8403
# Epoch 23/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.1363 - accuracy: 0.6716 - val_loss: 0.7934 - val_accuracy: 0.8335
# Epoch 24/30
# 401/401 [==============================] - 40s 101ms/step - loss: 1.1174 - accuracy: 0.6744 - val_loss: 0.8088 - val_accuracy: 0.8403
# Epoch 25/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.1163 - accuracy: 0.6785 - val_loss: 0.7821 - val_accuracy: 0.8313
# Epoch 26/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.1034 - accuracy: 0.6782 - val_loss: 0.7553 - val_accuracy: 0.8358
# Epoch 27/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.0924 - accuracy: 0.6797 - val_loss: 0.7343 - val_accuracy: 0.8414
# Epoch 28/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.0775 - accuracy: 0.6805 - val_loss: 0.7443 - val_accuracy: 0.8392
# Epoch 29/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.0601 - accuracy: 0.6827 - val_loss: 0.7358 - val_accuracy: 0.8381
# Epoch 30/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.0661 - accuracy: 0.6866 - val_loss: 0.7016 - val_accuracy: 0.8392

# %%
visualize_performance(
    model_name = VGG16_name,
    history = history
)

# %%
VGG16_model, test_loss, VGG16_test_acc = evaluate_model(
    model_name = VGG16_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels,
    testimages = testimages,
    testlabels = testlabels
)
# Out:
# Evaluating VGG-16 model...
#
# 251/251 [==============================] - 17s 32ms/step - loss: 0.9469 - accuracy: 0.7031
# Train loss = 0.946905791759491  ;  Train accuracy = 70.31%
#
# 28/28 [==============================] - 2s 57ms/step - loss: 0.6627 - accuracy: 0.8301
# Validation loss = 0.6627459526062012  ;  Validation accuracy = 83.01%
#
# 35/35 [==============================] - 2s 45ms/step - loss: 0.6718 - accuracy: 0.8404
# Test loss = 0.6718075275421143  ;  Test accuracy = 84.04%

# %%
train_pred, train_pred_classes, test_pred, test_pred_classes = computing_prediction(
    model = VGG16_model,
    model_name = VGG16_name,
    trainimages = trainimages,
    testimages = testimages
)

test_pred, test_pred_classes
# Out:
# Computing predictions for VGG-16...
# (array([[6.0839239e-03, 1.1190802e-02, 3.6559060e-02, ..., 3.3552755e-02,
#          8.8231367e-01, 1.6580665e-02],
#         [5.3086113e-03, 1.9014198e-02, 4.4333350e-02, ..., 3.9628174e-02,
#          8.7572467e-01, 8.6886073e-03],
#         [8.4553343e-05, 1.2248260e-04, 5.4995362e-03, ..., 1.1236860e-02,
#          9.8277426e-01, 2.6766274e-05],
#         ...,
#         [5.4199374e-03, 6.8790852e-03, 4.4276044e-02, ..., 6.2543526e-02,
#          8.7454385e-01, 1.5041999e-03],
#         [2.0373765e-02, 3.0353475e-02, 7.2119556e-02, ..., 4.6241589e-02,
#          8.1114042e-01, 4.1467715e-03],
#         [8.6091243e-02, 1.6567433e-01, 2.5681385e-01, ..., 1.0032386e-01,
#          2.8154370e-01, 4.2222783e-02]], dtype=float32),
#  array([5, 5, 5, ..., 5, 5, 5]))

# %%
model_report(
    model_name = VGG16_name,
    trainlabels = trainlabels,
    train_pred_classes = train_pred_classes,
    testlabels = testlabels,
    test_pred_classes = test_pred_classes,
    lesion_type_dict = lesion_type_dict
)
# Out:
# Model report for VGG-16 model ->
#
#
# Train Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       1.00      0.00      0.01       264
#           Melanocytic nevi       0.51      0.39      0.44       452
#             Dermatofibroma       0.52      0.23      0.32       945
#                   Melanoma       0.00      0.00      0.00       101
#           Vascular lesions       0.65      0.20      0.31      1029
#       Basal cell carcinoma       0.73      0.98      0.83      5110
#          Actinic keratoses       0.89      0.26      0.40       128
#
#                   accuracy                           0.70      8029
#                  macro avg       0.61      0.29      0.33      8029
#               weighted avg       0.68      0.70      0.64      8029
#
# Test Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.00      0.00      0.00        32
#           Melanocytic nevi       0.47      0.23      0.31        35
#             Dermatofibroma       0.40      0.35      0.37        84
#                   Melanoma       0.00      0.00      0.00        10
#           Vascular lesions       0.50      0.11      0.19        35
#       Basal cell carcinoma       0.88      0.99      0.93       895
#          Actinic keratoses       1.00      0.25      0.40        12
#
#                   accuracy                           0.84      1103
#                  macro avg       0.46      0.27      0.31      1103
#               weighted avg       0.79      0.84      0.80      1103

# %% [markdown]
# # 15. VGG-19 model

# %%
VGG19_name = 'VGG-19'

# %%
vgg19 = VGG19(
    include_top=False,
    input_shape=image_shape,
    pooling = 'avg',
    weights='imagenet'
)

VGG19_model = build_model(
    base_model = vgg19,
    base_model_name = VGG19_name,
    model_optimizer = RMSprop(lr=0.0001, epsilon=None, decay=1e-6)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Building VGG-19 model...

# %%
visualize_model(model = VGG19_model, model_name = VGG19_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 512)               20024384
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 20,090,951
# Trainable params: 66,567
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %%
history = fit_model(    
    model = VGG19_model,
    model_name = VGG19_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels
)
# Out:
# Fitting VGG-19 model...
# Epoch 1/30
# 401/401 [==============================] - 45s 108ms/step - loss: 9.9921 - accuracy: 0.4399 - val_loss: 4.8472 - val_accuracy: 0.8063
# Epoch 2/30
# 401/401 [==============================] - 41s 102ms/step - loss: 6.6563 - accuracy: 0.5154 - val_loss: 3.7811 - val_accuracy: 0.7973
# Epoch 3/30
# 401/401 [==============================] - 41s 103ms/step - loss: 4.9921 - accuracy: 0.5388 - val_loss: 3.3251 - val_accuracy: 0.8052
# Epoch 4/30
# 401/401 [==============================] - 42s 104ms/step - loss: 3.9079 - accuracy: 0.5606 - val_loss: 2.9144 - val_accuracy: 0.7882
# Epoch 5/30
# 401/401 [==============================] - 44s 110ms/step - loss: 3.1764 - accuracy: 0.5828 - val_loss: 2.5264 - val_accuracy: 0.7780
# Epoch 6/30
# 401/401 [==============================] - 43s 107ms/step - loss: 2.6785 - accuracy: 0.5933 - val_loss: 2.1202 - val_accuracy: 0.7961
# Epoch 7/30
# 401/401 [==============================] - 43s 108ms/step - loss: 2.3386 - accuracy: 0.6118 - val_loss: 1.8821 - val_accuracy: 0.8007
# Epoch 8/30
# 401/401 [==============================] - 42s 105ms/step - loss: 2.0627 - accuracy: 0.6198 - val_loss: 1.6731 - val_accuracy: 0.8086
# Epoch 9/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.8756 - accuracy: 0.6263 - val_loss: 1.5177 - val_accuracy: 0.8052
# Epoch 10/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.7237 - accuracy: 0.6323 - val_loss: 1.3903 - val_accuracy: 0.8063
# Epoch 11/30
# 401/401 [==============================] - 43s 107ms/step - loss: 1.6400 - accuracy: 0.6365 - val_loss: 1.3072 - val_accuracy: 0.8041
# Epoch 12/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.5338 - accuracy: 0.6400 - val_loss: 1.2507 - val_accuracy: 0.8063
# Epoch 13/30
# 401/401 [==============================] - 43s 106ms/step - loss: 1.4560 - accuracy: 0.6496 - val_loss: 1.1658 - val_accuracy: 0.8256
# Epoch 14/30
# 401/401 [==============================] - 43s 107ms/step - loss: 1.4053 - accuracy: 0.6518 - val_loss: 1.0887 - val_accuracy: 0.8290
# Epoch 15/30
# 401/401 [==============================] - 43s 106ms/step - loss: 1.3700 - accuracy: 0.6533 - val_loss: 1.0873 - val_accuracy: 0.8211
# Epoch 16/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.3096 - accuracy: 0.6604 - val_loss: 1.0219 - val_accuracy: 0.8245
# Epoch 17/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.2943 - accuracy: 0.6591 - val_loss: 0.9722 - val_accuracy: 0.8369
# Epoch 18/30
# 401/401 [==============================] - 44s 109ms/step - loss: 1.2556 - accuracy: 0.6629 - val_loss: 0.9335 - val_accuracy: 0.8437
# Epoch 19/30
# 401/401 [==============================] - 43s 107ms/step - loss: 1.2153 - accuracy: 0.6611 - val_loss: 0.9233 - val_accuracy: 0.8233
# Epoch 20/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.1830 - accuracy: 0.6650 - val_loss: 0.8521 - val_accuracy: 0.8301
# Epoch 21/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.1671 - accuracy: 0.6667 - val_loss: 0.8351 - val_accuracy: 0.8426
# Epoch 22/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.1559 - accuracy: 0.6695 - val_loss: 0.8223 - val_accuracy: 0.8392
# Epoch 23/30
# 401/401 [==============================] - 43s 107ms/step - loss: 1.1244 - accuracy: 0.6815 - val_loss: 0.7987 - val_accuracy: 0.8448
# Epoch 24/30
# 401/401 [==============================] - 45s 111ms/step - loss: 1.1128 - accuracy: 0.6751 - val_loss: 0.7956 - val_accuracy: 0.8324
# Epoch 25/30
# 401/401 [==============================] - 43s 108ms/step - loss: 1.1028 - accuracy: 0.6819 - val_loss: 0.7206 - val_accuracy: 0.8369
# Epoch 26/30
# 401/401 [==============================] - 43s 108ms/step - loss: 1.0963 - accuracy: 0.6779 - val_loss: 0.7233 - val_accuracy: 0.8381
# Epoch 27/30
# 401/401 [==============================] - 42s 105ms/step - loss: 1.0823 - accuracy: 0.6791 - val_loss: 0.7558 - val_accuracy: 0.8471
# Epoch 28/30
# 401/401 [==============================] - 43s 108ms/step - loss: 1.0753 - accuracy: 0.6751 - val_loss: 0.7322 - val_accuracy: 0.8347
# Epoch 29/30
# 401/401 [==============================] - 42s 106ms/step - loss: 1.0622 - accuracy: 0.6784 - val_loss: 0.7389 - val_accuracy: 0.8482
# Epoch 30/30
# 401/401 [==============================] - 43s 108ms/step - loss: 1.0614 - accuracy: 0.6862 - val_loss: 0.7138 - val_accuracy: 0.8448

# %%
visualize_performance(
    model_name = VGG19_name,
    history = history
)

# %%
VGG19_model, test_loss, VGG19_test_acc = evaluate_model(
    model_name = VGG19_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels,
    testimages = testimages,
    testlabels = testlabels
)
# Out:
# Evaluating VGG-19 model...
#
# 251/251 [==============================] - 19s 38ms/step - loss: 0.9636 - accuracy: 0.7007
# Train loss = 0.963555634021759  ;  Train accuracy = 70.07%
#
# 28/28 [==============================] - 2s 63ms/step - loss: 0.6447 - accuracy: 0.8324
# Validation loss = 0.6447089910507202  ;  Validation accuracy = 83.24%
#
# 35/35 [==============================] - 2s 51ms/step - loss: 0.6557 - accuracy: 0.8377
# Test loss = 0.6556998491287231  ;  Test accuracy = 83.77%

# %%
train_pred, train_pred_classes, test_pred, test_pred_classes = computing_prediction(
    model = VGG19_model,
    model_name = VGG19_name,
    trainimages = trainimages,
    testimages = testimages
)

test_pred, test_pred_classes
# Out:
# Computing predictions for VGG-19...
# (array([[1.0344097e-03, 8.0180783e-03, 1.2315180e-02, ..., 2.0513570e-02,
#          9.5035785e-01, 5.1598749e-03],
#         [9.2696678e-03, 3.9419185e-02, 4.9801689e-02, ..., 6.0588066e-02,
#          7.9498923e-01, 3.1476837e-02],
#         [2.7442822e-05, 1.1684045e-04, 4.1012079e-03, ..., 2.4534181e-02,
#          9.7118515e-01, 1.3378773e-05],
#         ...,
#         [2.1743684e-03, 6.8271230e-03, 2.2932993e-02, ..., 3.5919093e-02,
#          9.2755365e-01, 1.7128760e-03],
#         [7.7936295e-03, 9.5361911e-02, 2.8331686e-02, ..., 1.9641684e-02,
#          8.3637166e-01, 5.2518300e-03],
#         [3.5470542e-02, 9.8795690e-02, 4.0055558e-01, ..., 1.1286656e-01,
#          3.1792846e-01, 1.5806468e-02]], dtype=float32),
#  array([5, 5, 5, ..., 5, 5, 2]))

# %%
model_report(
    model_name = VGG19_name,
    trainlabels = trainlabels,
    train_pred_classes = train_pred_classes,
    testlabels = testlabels,
    test_pred_classes = test_pred_classes,
    lesion_type_dict = lesion_type_dict
)
# Out:
# Model report for VGG-19 model ->
#
#
# Train Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.78      0.05      0.10       264
#           Melanocytic nevi       0.55      0.26      0.35       452
#             Dermatofibroma       0.47      0.34      0.40       945
#                   Melanoma       0.00      0.00      0.00       101
#           Vascular lesions       0.63      0.17      0.26      1029
#       Basal cell carcinoma       0.73      0.98      0.84      5110
#          Actinic keratoses       0.93      0.10      0.18       128
#
#                   accuracy                           0.70      8029
#                  macro avg       0.58      0.27      0.30      8029
#               weighted avg       0.67      0.70      0.64      8029
#
# Test Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       1.00      0.03      0.06        32
#           Melanocytic nevi       0.33      0.09      0.14        35
#             Dermatofibroma       0.36      0.43      0.39        84
#                   Melanoma       0.00      0.00      0.00        10
#           Vascular lesions       0.20      0.03      0.05        35
#       Basal cell carcinoma       0.89      0.99      0.94       895
#          Actinic keratoses       1.00      0.08      0.15        12
#
#                   accuracy                           0.84      1103
#                  macro avg       0.54      0.23      0.25      1103
#               weighted avg       0.81      0.84      0.80      1103

# %% [markdown]
# # 16. GoogLeNet model

# %%
def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
    # Input: 
    # - f1: number of filters of the 1x1 convolutional layer in the first path
    # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
    # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
    # - f4: number of filters of the 1x1 convolutional layer in the fourth path

    # 1st path:
    path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

    # 2nd path
    path2 = Conv2D(filters = f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
    path2 = Conv2D(filters = f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

    # 3rd path
    path3 = Conv2D(filters = f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
    path3 = Conv2D(filters = f3_conv5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

    # 4th path
    path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
    path4 = Conv2D(filters = f4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

    output_layer = concatenate([path1, path2, path3, path4], axis = -1)

    return output_layer

# %%
def GoogLeNet(input_shape, num_classes):
    # input layer 
    input_layer = Input(shape = input_shape)

    # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
    X = Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

    # max-pooling layer: pool_size = (3,3), strides = 2
    X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

    # convolutional layer: filters = 64, strides = 1
    X = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

    # convolutional layer: filters = 192, kernel_size = (3,3)
    X = Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

    # max-pooling layer: pool_size = (3,3), strides = 2
    X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

    # 1st Inception block
    X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

    # 2nd Inception block
    X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

    # max-pooling layer: pool_size = (3,3), strides = 2
    X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

    # 3rd Inception block
    X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)

    # Extra network 1:
    # X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    # X1 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
    # X1 = Flatten()(X1)
    # X1 = Dense(1024, activation = 'relu')(X1)
    # X1 = Dropout(0.7)(X1)
    # X1 = Dense(num_classes, activation = 'softmax')(X1)


    # 4th Inception block
    X = Inception_block(X, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

    # 5th Inception block
    X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

    # 6th Inception block
    X = Inception_block(X, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)

    # Extra network 2:
    # X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    # X2 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
    # X2 = Flatten()(X2)
    # X2 = Dense(1024, activation = 'relu')(X2)
    # X2 = Dropout(0.7)(X2)
    # X2 = Dense(num_classes, activation = 'softmax')(X2)


    # 7th Inception block
    X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, 
                      f3_conv5 = 128, f4 = 128)

    # max-pooling layer: pool_size = (3,3), strides = 2
    X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

    # 8th Inception block
    X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

    # 9th Inception block
    X = Inception_block(X, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

    # Global Average pooling layer 
    X = GlobalAveragePooling2D(name = 'GAPL')(X)

    # Dropoutlayer 
    X = Dropout(0.4)(X)

    # output layer 
    X = Dense(num_classes, activation = 'softmax', name='output')(X)

    # model
    # model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet')
    model = Model(input_layer, X, name = 'GoogLeNet')

    return model

# %%
GoogLeNet_name = 'GoogLeNet'

# %%
googlenet = GoogLeNet(
    input_shape=image_shape,
    num_classes=num_classes
)

GoogLeNet_model = build_model(
    base_model = googlenet,
    base_model_name = GoogLeNet_name,
    model_optimizer = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True),
    raw_model = True
)
# Out:
# Building GoogLeNet model...

# %%
visualize_model(model = GoogLeNet_model, model_name = GoogLeNet_name)
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 112, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 53, 72, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 26, 35, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 26, 35, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 26, 35, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 17, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 17, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 17, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 17, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 17, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 12, 17, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 17, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 12, 17, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 17, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 17, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 12, 17, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 17, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 17, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 12, 17, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 17, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 12, 17, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 17, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 8, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 5, 8, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 5, 8, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 5, 8, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 5, 8, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 5, 8, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 5, 8, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 5, 8, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 8, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 5, 8, 112)    57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 5, 8, 24)     12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 5, 8, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 5, 8, 160)    82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 5, 8, 224)    226016      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 5, 8, 64)     38464       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 5, 8, 64)     32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 5, 8, 512)    0           conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 5, 8, 128)    65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 5, 8, 24)     12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 5, 8, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 5, 8, 128)    65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 5, 8, 256)    295168      conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 5, 8, 64)     38464       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 5, 8, 64)     32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 5, 8, 512)    0           conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 5, 8, 144)    73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 5, 8, 32)     16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 5, 8, 512)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 5, 8, 112)    57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 5, 8, 288)    373536      conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 5, 8, 64)     51264       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 5, 8, 64)     32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 5, 8, 528)    0           conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 5, 8, 160)    84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 5, 8, 32)     16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 5, 8, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 5, 8, 256)    135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 5, 8, 320)    461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 5, 8, 128)    102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 5, 8, 128)    67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 5, 8, 832)    0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 2, 3, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 2, 3, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 2, 3, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 2, 3, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 2, 3, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 2, 3, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 2, 3, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 2, 3, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 2, 3, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 2, 3, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 2, 3, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 2, 3, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 2, 3, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 2, 3, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 2, 3, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 2, 3, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 2, 3, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# GAPL (GlobalAveragePooling2D)   (None, 1024)         0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           GAPL[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            7175        dropout[0][0]
# ==================================================================================================
# Total params: 5,980,727
# Trainable params: 0
# Non-trainable params: 5,980,727
# __________________________________________________________________________________________________
# None

# %%
history = fit_model(    
    model = GoogLeNet_model,
    model_name = GoogLeNet_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels
)
# Out:
# Fitting GoogLeNet model...
# Epoch 1/30
# 401/401 [==============================] - 46s 106ms/step - loss: 1.7982 - accuracy: 0.3092 - val_loss: 1.6762 - val_accuracy: 0.6874
# Epoch 2/30
# 401/401 [==============================] - 40s 101ms/step - loss: 1.7896 - accuracy: 0.3205 - val_loss: 1.6766 - val_accuracy: 0.7044
# Epoch 3/30
# 401/401 [==============================] - 41s 103ms/step - loss: 1.7925 - accuracy: 0.3107 - val_loss: 1.6768 - val_accuracy: 0.7044
# Epoch 4/30
# 401/401 [==============================] - 39s 97ms/step - loss: 1.7892 - accuracy: 0.3169 - val_loss: 1.6777 - val_accuracy: 0.7089
# Epoch 5/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7939 - accuracy: 0.3120 - val_loss: 1.6763 - val_accuracy: 0.7089
# Epoch 6/30
# 401/401 [==============================] - 41s 102ms/step - loss: 1.7974 - accuracy: 0.3130 - val_loss: 1.6760 - val_accuracy: 0.6829
# Epoch 7/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7960 - accuracy: 0.3129 - val_loss: 1.6764 - val_accuracy: 0.7010
# Epoch 8/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7926 - accuracy: 0.3138 - val_loss: 1.6774 - val_accuracy: 0.7135
# Epoch 9/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.7969 - accuracy: 0.3049 - val_loss: 1.6769 - val_accuracy: 0.6931
# Epoch 10/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7974 - accuracy: 0.3088 - val_loss: 1.6758 - val_accuracy: 0.7022
# Epoch 11/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.8001 - accuracy: 0.3057 - val_loss: 1.6755 - val_accuracy: 0.7089
# Epoch 12/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.7942 - accuracy: 0.3115 - val_loss: 1.6763 - val_accuracy: 0.6863
# Epoch 13/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7962 - accuracy: 0.3110 - val_loss: 1.6776 - val_accuracy: 0.6976
# Epoch 14/30
# 401/401 [==============================] - 39s 97ms/step - loss: 1.7994 - accuracy: 0.3079 - val_loss: 1.6755 - val_accuracy: 0.7044
# Epoch 15/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.8026 - accuracy: 0.3116 - val_loss: 1.6771 - val_accuracy: 0.6829
# Epoch 16/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.7971 - accuracy: 0.3075 - val_loss: 1.6771 - val_accuracy: 0.6976
# Epoch 17/30
# 401/401 [==============================] - 39s 97ms/step - loss: 1.7973 - accuracy: 0.3128 - val_loss: 1.6743 - val_accuracy: 0.7022
# Epoch 18/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7937 - accuracy: 0.3156 - val_loss: 1.6768 - val_accuracy: 0.6999
# Epoch 19/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7937 - accuracy: 0.3145 - val_loss: 1.6753 - val_accuracy: 0.7022
# Epoch 20/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.7962 - accuracy: 0.3143 - val_loss: 1.6774 - val_accuracy: 0.6908
# Epoch 21/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.8041 - accuracy: 0.3034 - val_loss: 1.6763 - val_accuracy: 0.6874
# Epoch 22/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7999 - accuracy: 0.3087 - val_loss: 1.6772 - val_accuracy: 0.7112
# Epoch 23/30
# 401/401 [==============================] - 39s 97ms/step - loss: 1.8026 - accuracy: 0.3002 - val_loss: 1.6754 - val_accuracy: 0.7101
# Epoch 24/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7889 - accuracy: 0.3102 - val_loss: 1.6753 - val_accuracy: 0.7044
# Epoch 25/30
# 401/401 [==============================] - 39s 98ms/step - loss: 1.7999 - accuracy: 0.2982 - val_loss: 1.6749 - val_accuracy: 0.6999
# Epoch 26/30
# 401/401 [==============================] - 40s 100ms/step - loss: 1.7980 - accuracy: 0.3088 - val_loss: 1.6761 - val_accuracy: 0.6954
# Epoch 27/30
# 401/401 [==============================] - 40s 99ms/step - loss: 1.8012 - accuracy: 0.3043 - val_loss: 1.6781 - val_accuracy: 0.7067

# %%
visualize_performance(
    model_name = GoogLeNet_name,
    history = history
)

# %%
GoogLeNet_model, test_loss, GoogLeNet_test_acc = evaluate_model(
    model_name = GoogLeNet_name,
    trainimages = trainimages,
    trainlabels = trainlabels,
    validationimages = validationimages,
    validationlabels = validationlabels,
    testimages = testimages,
    testlabels = testlabels
)
# Out:
# Evaluating GoogLeNet model...
#
# 251/251 [==============================] - 13s 19ms/step - loss: 1.7446 - accuracy: 0.5612
# Train loss = 1.744604229927063  ;  Train accuracy = 56.12%
#
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6760 - accuracy: 0.6874
# Validation loss = 1.6760263442993164  ;  Validation accuracy = 68.74%
#
# 35/35 [==============================] - 1s 24ms/step - loss: 1.6566 - accuracy: 0.6999
# Test loss = 1.6565957069396973  ;  Test accuracy = 69.99%

# %%
train_pred, train_pred_classes, test_pred, test_pred_classes = computing_prediction(
    model = GoogLeNet_model,
    model_name = GoogLeNet_name,
    trainimages = trainimages,
    testimages = testimages
)

test_pred, test_pred_classes
# Out:
# Computing predictions for GoogLeNet...
# (array([[0.09359553, 0.138751  , 0.10461356, ..., 0.11312931, 0.20579   ,
#          0.15013716],
#         [0.12045312, 0.13151275, 0.13573582, ..., 0.12829898, 0.17580293,
#          0.14744744],
#         [0.08568761, 0.13085276, 0.09791209, ..., 0.09805001, 0.22460571,
#          0.14126436],
#         ...,
#         [0.08995656, 0.11042912, 0.10102667, ..., 0.11408326, 0.21734057,
#          0.15476996],
#         [0.10047606, 0.12443498, 0.11214502, ..., 0.11368763, 0.19989668,
#          0.15571368],
#         [0.10773835, 0.13780954, 0.12024797, ..., 0.12634093, 0.18396713,
#          0.14590524]], dtype=float32),
#  array([5, 5, 5, ..., 5, 5, 5]))

# %%
model_report(
    model_name = GoogLeNet_name,
    trainlabels = trainlabels,
    train_pred_classes = train_pred_classes,
    testlabels = testlabels,
    test_pred_classes = test_pred_classes,
    lesion_type_dict = lesion_type_dict
)
# Out:
# Model report for GoogLeNet model ->
#
#
# Train Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.00      0.00      0.00       264
#           Melanocytic nevi       0.00      0.00      0.00       452
#             Dermatofibroma       0.00      0.00      0.00       945
#                   Melanoma       0.01      0.12      0.02       101
#           Vascular lesions       0.00      0.00      0.00      1029
#       Basal cell carcinoma       0.67      0.88      0.76      5110
#          Actinic keratoses       0.00      0.00      0.00       128
#
#                   accuracy                           0.56      8029
#                  macro avg       0.10      0.14      0.11      8029
#               weighted avg       0.43      0.56      0.48      8029
#
# Test Report :
#                              precision    recall  f1-score   support
#
# Pigmented Benign keratosis       0.00      0.00      0.00        32
#           Melanocytic nevi       0.00      0.00      0.00        35
#             Dermatofibroma       0.00      0.00      0.00        84
#                   Melanoma       0.02      0.30      0.03        10
#           Vascular lesions       0.00      0.00      0.00        35
#       Basal cell carcinoma       0.85      0.86      0.85       895
#          Actinic keratoses       0.00      0.00      0.00        12
#
#                   accuracy                           0.70      1103
#                  macro avg       0.12      0.17      0.13      1103
#               weighted avg       0.69      0.70      0.69      1103

# %% [markdown]
# # 17. Summary

# %%
pd.DataFrame.from_dict(
    dict(
        Model    = [ResNet50_name,     InceptionV3_name,     VGG16_name,     VGG19_name,     GoogLeNet_name],
        Accuracy = [ResNet50_test_acc, InceptionV3_test_acc, VGG16_test_acc, VGG19_test_acc, GoogLeNet_test_acc],
    )
).style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_362d8_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_362d8_row0_col0" class="data row0 col0" >ResNet50</td>
#       <td id="T_362d8_row0_col1" class="data row0 col1" >86.400000</td>
#     </tr>
#     <tr>
#       <td id="T_362d8_row1_col0" class="data row1 col0" >InceptionV3</td>
#       <td id="T_362d8_row1_col1" class="data row1 col1" >82.410000</td>
#     </tr>
#     <tr>
#       <td id="T_362d8_row2_col0" class="data row2 col0" >VGG-16</td>
#       <td id="T_362d8_row2_col1" class="data row2 col1" >84.040000</td>
#     </tr>
#     <tr>
#       <td id="T_362d8_row3_col0" class="data row3 col0" >VGG-19</td>
#       <td id="T_362d8_row3_col1" class="data row3 col1" >83.770000</td>
#     </tr>
#     <tr>
#       <td id="T_362d8_row4_col0" class="data row4 col0" >GoogLeNet</td>
#       <td id="T_362d8_row4_col1" class="data row4 col1" >69.990000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 18. References
#
#
# - [Article] [Kaiming He et al Deep Residual Learning for Image Recognition. (CVPR 2015)](https://arxiv.org/abs/1512.03385)
# - [Image] [A Basic Residual Block](https://medium.datadriveninvestor.com/developing-with-keras-functional-api-6017828408cd)
# - [Image] [Deep Feature-Based Classifiers for Fruit Fly Identification (Diptera: Tephritidae)](https://www.researchgate.net/figure/VGG16-VGG19-Inception-V3-Xception-and-ResNet-50-architectures_fig1_330478807)
# - [Image] [Googlenet/InceptionV1 architecture](https://developer.ridgerun.com/wiki/index.php?title=GstInference/Supported_architectures/InceptionV2)
# - [Notebook] [skin cancer resnet50](https://www.kaggle.com/code/zhyaqi/skin-cancer-resnet50)
# - [Notebook] [MinorProject_skinLesions](https://www.kaggle.com/code/nancybhargava/minorproject-skinlesions)
